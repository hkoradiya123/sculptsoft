# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-3-5-haiku-20241022"

# %%
def add_user_message(conversation, content):
    conversation.append({
        "role": "user",
        "content": content
    })


def add_assistant_message(conversation, content):
    conversation.append({
        "role": "assistant",
        "content": content.replace("**", "").replace("##", " ")
    })

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature
    }

    if system:
        params["system"] = system
    
    if stop_sequences:
        params["stop_sequences"] = stop_sequences
        
    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


# def generate_dataset():

prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

# %%
messages = []

add_user_message(messages, prompt)
add_assistant_message(messages, "```json")
text = chat(messages, stop_sequences=["```"])
print(json.loads(text))
# add_user_message(messages, prompt)
# Out:
# C:\Users\korad\AppData\Local\Temp\ipykernel_13852\3827356766.py:26: DeprecationWarning: The model 'claude-3-5-haiku-20241022' is deprecated and will reach end-of-life on February 19th, 2026.
# Please migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.
#   message = client.messages.create(**params)
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[5], line 5
#       1 messages = []
#       2
#       3 add_user_message(messages, prompt)
#       4 add_assistant_message(messages, "```json")
# ----> 5 text = chat(messages, stop_sequences=["```"])
#       6 print(json.loads(text))
#       7 # add_user_message(messages, prompt)
#       8
#
# Cell In[3], line 26, in chat(messages, system, temperature, stop_sequences)
#      22
#      23     if stop_sequences:
#      24         params["stop_sequences"] = stop_sequences
#      25
# ---> 26     message = client.messages.create(**params)
#      27     return message.content[0].text
#
# File d:\HARSH\Sculptsoft\.venv\Lib\site-packages\anthropic\_utils\_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File d:\HARSH\Sculptsoft\.venv\Lib\site-packages\anthropic\resources\messages\messages.py:1009, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#    1002 if model in MODELS_TO_WARN_WITH_THINKING_ENABLED and thinking and thinking["type"] == "enabled":
#    1003     warnings.warn(
#    1004         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#    1005         UserWarning,
#    1006         stacklevel=3,
#    1007     )
# -> 1009 return self._post(
#    1010     "/v1/messages",
#    1011     body=maybe_transform(
#    1012         {
#    1013             "max_tokens": max_tokens,
#    1014             "messages": messages,
#    1015             "model": model,
#    1016             "cache_control": cache_control,
#    1017             "container": container,
#    1018             "inference_geo": inference_geo,
#    1019             "metadata": metadata,
#    1020             "output_config": output_config,
#    1021             "service_tier": service_tier,
#    1022             "stop_sequences": stop_sequences,
#    1023             "stream": stream,
#    1024             "system": system,
#    1025             "temperature": temperature,
#    1026             "thinking": thinking,
#    1027             "tool_choice": tool_choice,
#    1028             "tools": tools,
#    1029             "top_k": top_k,
#    1030             "top_p": top_p,
#    1031         },
#    1032         message_create_params.MessageCreateParamsStreaming
#    1033         if stream
#    1034         else message_create_params.MessageCreateParamsNonStreaming,
#    1035     ),
#    1036     options=make_request_options(
#    1037         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1038     ),
#    1039     cast_to=Message,
#    1040     stream=stream or False,
#    1041     stream_cls=Stream[RawMessageStreamEvent],
#    1042 )
#
# File d:\HARSH\Sculptsoft\.venv\Lib\site-packages\anthropic\_base_client.py:1535, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1526     warnings.warn(
#    1527         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1528         "Please pass raw bytes via the `content` parameter instead.",
#    1529         DeprecationWarning,
#    1530         stacklevel=2,
#    1531     )
#    1532 opts = FinalRequestOptions.construct(
#    1533     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1534 )
# -> 1535 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\HARSH\Sculptsoft\.venv\Lib\site-packages\anthropic\_base_client.py:1194, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1191     if not response.is_closed:
#    1192         response.read()
# -> 1194     raise self._make_status_error_from_response(response) from None
#    1196 raise RuntimeError("could not resolve response (should never happen)")
#
# NotFoundError: Error code: 404 - {'type': 'error', 'error': {'type': 'not_found_error', 'message': 'model: claude-3-5-haiku-20241022'}, 'request_id': 'req_011CcCY5No9bf5boyFXh6xBc'}
